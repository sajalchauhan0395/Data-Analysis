# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('supermarket_sales.csv')

# %%
df1.keys()
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df1.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df1.drop(['cogs','gross margin percentage'], axis=1, inplace =True) #droping unrelated columns

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Tax 5%         1000 non-null   float64
#  9   Total          1000 non-null   float64
#  10  Date           1000 non-null   object
#  11  Time           1000 non-null   object
#  12  Payment        1000 non-null   object
#  13  gross income   1000 non-null   float64
#  14  Rating         1000 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 117.3+ KB

# %%
pd.isnull(df1) #if there is value there value false
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment  gross income  \
# ...

# %%
df1.sample() #random sample
# Out:
#       Invoice ID Branch    City Customer type  Gender        Product line  \
# 859  316-66-3011      A  Yangon        Member  Female  Food and beverages
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time Payment  \
# 859       47.63         9  21.4335  450.1035  1/23/2019  12:35    Cash
#
#      gross income  Rating
# 859       21.4335     5.0

# %%
df1.describe() #includes minimum, maximum, mean (central tendency), standard deviation (dispersion) of the values in numerical columns, and the count of all non-null values in the data, as shown below
# Out:
#         Unit price     Quantity       Tax 5%        Total  gross income  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean     55.672130     5.510000    15.379369   322.966749     15.379369
# std      26.494628     2.923431    11.708825   245.885335     11.708825
# min      10.080000     1.000000     0.508500    10.678500      0.508500
# 25%      32.875000     3.000000     5.924875   124.422375      5.924875
# 50%      55.230000     5.000000    12.088000   253.848000     12.088000
# 75%      77.935000     8.000000    22.445250   471.350250     22.445250
# max      99.960000    10.000000    49.650000  1042.650000     49.650000
#
#            Rating
# count  1000.00000
# mean      6.97270
# std       1.71858
# min       4.00000
# 25%       5.50000
# 50%       7.00000
# 75%       8.50000
# max      10.00000

# %%
df1.query("Rating >= 7.0") #Query for rating above 7.0
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 982  139-32-4183      A     Yangon        Member  Female
# 985  374-38-5555      B   Mandalay        Normal  Female
# 989  430-53-4718      B   Mandalay        Member    Male
# 992  745-74-0715      A     Yangon        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
df1.query("Quantity > 5")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# ..           ...    ...        ...           ...     ...
# 989  430-53-4718      B   Mandalay        Member    Male
# 991  602-16-6955      B   Mandalay        Normal  Female
# 993  690-01-6631      B   Mandalay        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
df1.loc[560,"Product line"] #loc helps in locating which product line is used on index 560
# Out:
# 'Electronic accessories'

# %%
df1["Payment"].unique() #unique payment method used by customers
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
df1.sort_values("Rating")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 848  845-94-6841      C  Naypyitaw        Member  Female
# 672  576-31-4774      B   Mandalay        Normal  Female
# 72   510-95-6347      B   Mandalay        Member  Female
# 618  828-46-6863      A     Yangon        Member    Male
# 876  885-56-0389      C  Naypyitaw        Member    Male
# ..           ...    ...        ...           ...     ...
# 62   347-34-2234      B   Mandalay        Member  Female
# 60   285-68-5083      C  Naypyitaw        Member  Female
# 159  423-57-2993      B   Mandalay        Normal    Male
# 853  866-70-2814      B   Mandalay        Normal  Female
# 387  725-56-0833      A     Yangon        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 848      Food and beverages       72.88         9  32.7960  688.7160
# 672       Health and beauty       73.41         3  11.0115  231.2415
# 72       Food and beverages       48.52         3   7.2780  152.8380
# ...

# %%
df1.value_counts("Product line") #function returns — how many times a value appeared in a column
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
df2 = df1.nlargest(10,"Unit price")

# %%
df2
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 122  219-22-9386      B   Mandalay        Member    Male
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 930  641-62-7288      B   Mandalay        Normal    Male
# 494  437-53-3084      B   Mandalay        Normal    Male
# 283  667-92-0055      A     Yangon        Member    Male
# 300  446-47-6729      C  Naypyitaw        Normal    Male
# 941  702-83-5291      C  Naypyitaw        Member    Male
# 362  471-41-2823      C  Naypyitaw        Normal    Male
# 326  815-11-1168      A     Yangon        Member    Male
# 209  817-69-8206      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 122       Sports and travel       99.96         9  44.9820  944.6220
# 983       Health and beauty       99.96         7  34.9860  734.7060
# 930      Home and lifestyle       99.92         6  29.9760  629.4960
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
df1.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'gross income', 'Rating'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'Gender',data= df1)

for bars in ax.containers: #used to display values
    ax.bar_label(bars)

# %%
df1.groupby(['Gender'], as_index = False)['Payment'].sum().sort_values(by = 'Payment',ascending= False)
# Out:
#    Gender                                            Payment
# 0  Female  EwalletCashEwalletEwalletCredit cardCredit car...
# 1    Male  Credit cardEwalletEwalletEwalletCashEwalletCre...

# %%
df1.sort_values('Payment')
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 499  420-18-8989      A     Yangon        Member  Female
# 483  305-18-3552      B   Mandalay        Member    Male
# 481  246-11-3901      C  Naypyitaw        Normal  Female
# 480  541-08-3113      C  Naypyitaw        Normal    Male
# 474  676-39-6028      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 711  728-88-7867      C  Naypyitaw        Member  Female
# 92   873-51-0671      A     Yangon        Member  Female
# 709  445-30-9252      A     Yangon        Normal    Male
# 706  834-45-5519      B   Mandalay        Normal  Female
# 0    750-67-8428      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 499       Sports and travel       51.52         8  20.6080  432.7680
# 483      Home and lifestyle       60.38        10  30.1900  633.9900
# 481  Electronic accessories       32.80        10  16.4000  344.4000
# ...

# %%
columns_to_select = ['City', 'Gender', 'Product line', 'Payment']

# %%
df3 = df1[columns_to_select].copy() #new table from existing table

# %%
df3.head(15)
# Out:
#          City  Gender            Product line      Payment
# 0      Yangon  Female       Health and beauty      Ewallet
# 1   Naypyitaw  Female  Electronic accessories         Cash
# 2      Yangon    Male      Home and lifestyle  Credit card
# 3      Yangon    Male       Health and beauty      Ewallet
# 4      Yangon    Male       Sports and travel      Ewallet
# 5   Naypyitaw    Male  Electronic accessories      Ewallet
# 6      Yangon  Female  Electronic accessories      Ewallet
# 7   Naypyitaw  Female      Home and lifestyle      Ewallet
# 8      Yangon  Female       Health and beauty  Credit card
# 9    Mandalay  Female      Food and beverages  Credit card
# 10   Mandalay  Female     Fashion accessories      Ewallet
# 11   Mandalay    Male  Electronic accessories         Cash
# 12     Yangon  Female  Electronic accessories      Ewallet
# 13     Yangon    Male      Food and beverages      Ewallet
# 14     Yangon  Female       Health and beauty         Cash

# %%
pay_df = ['Payment']

# %%
df4 = df1[pay_df].copy()

# %%
df4
# Out:
#          Payment
# 0        Ewallet
# 1           Cash
# 2    Credit card
# 3        Ewallet
# 4        Ewallet
# ..           ...
# 995      Ewallet
# 996      Ewallet
# 997         Cash
# 998         Cash
# 999         Cash
#
# [1000 rows x 1 columns]

# %% [markdown]
# Payment Method Distribution
#
# 3 Types of payment methods : Cash, Ewallet, credit Card

# %%
payment_counts = df4['Payment'].value_counts()
payment_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)

plt.title('Payment Method Distribution')

# Displaying the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
cust_type = ['Gender']
df5 = df1[cust_type].copy()

# %%
df5
# Out:
#      Gender
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# ..      ...
# 995    Male
# 996  Female
# 997    Male
# 998    Male
# 999  Female
#
# [1000 rows x 1 columns]

# %%
male_count = df5['Gender'].value_counts()['Male'] #Male Count

print("Number of males:", male_count)
# Out:
# Number of males: 499

# %%
female_count = df5['Gender'].value_counts()['Female'] #FeMale Count

print("Number of Females:", female_count)
# Out:
# Number of Females: 501

# %%
payment_counts = df5['Gender'].value_counts()
payment_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)

plt.title('Gender ')

# Displaying the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Tax 5%         1000 non-null   float64
#  9   Total          1000 non-null   float64
#  10  Date           1000 non-null   object
#  11  Time           1000 non-null   object
#  12  Payment        1000 non-null   object
#  13  gross income   1000 non-null   float64
#  14  Rating         1000 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 117.3+ KB

# %% [markdown]
# Payment distribution among Males

# %%
male_df = df1[df1['Gender'] == 'Male']
male_payment_counts = male_df['Payment'].value_counts() # Count the occurrences of each payment mode among males
male_payment_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)

plt.title('Payment Modes Distribution in Males')

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# Payment distribution among females

# %%
female_df = df1[df1['Gender'] == 'Female']
female_payment_counts = female_df['Payment'].value_counts() # Count the occurrences of each payment mode among females
female_payment_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)

plt.title('Payment Modes Distribution among females')

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df3
# Out:
#           City  Gender            Product line      Payment
# 0       Yangon  Female       Health and beauty      Ewallet
# 1    Naypyitaw  Female  Electronic accessories         Cash
# 2       Yangon    Male      Home and lifestyle  Credit card
# 3       Yangon    Male       Health and beauty      Ewallet
# 4       Yangon    Male       Sports and travel      Ewallet
# ..         ...     ...                     ...          ...
# 995  Naypyitaw    Male       Health and beauty      Ewallet
# 996   Mandalay  Female      Home and lifestyle      Ewallet
# 997     Yangon    Male      Food and beverages         Cash
# 998     Yangon    Male      Home and lifestyle         Cash
# 999     Yangon  Female     Fashion accessories         Cash
#
# [1000 rows x 4 columns]

# %% [markdown]
# Customer Types Normal or Member

# %%
cust_type = df1['Customer type'].value_counts()
cust_type.plot(kind='pie', autopct='%1.2f%%', startangle=90)

plt.title('Customer type ')

# Displaying the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
cust = df1['Customer type'].value_counts()['Normal'] #FeMale Count

print("Customers type:", cust)
# Out:
# Customers type: 499

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Tax 5%         1000 non-null   float64
#  9   Total          1000 non-null   float64
#  10  Date           1000 non-null   object
#  11  Time           1000 non-null   object
#  12  Payment        1000 non-null   object
#  13  gross income   1000 non-null   float64
#  14  Rating         1000 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 117.3+ KB

# %%
male_df = df1[df1['Gender'] == 'Male'],[['City'] == 'Yangon']

# %%
rows = pd.options.display.max_rows

# %%
rows
# Out:
# 60
